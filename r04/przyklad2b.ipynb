# %%
## Python

import numpy as np
def taxi_id_number(num_taxis): 
    arr = np.arange(num_taxis) 
    np.random.shuffle(arr)
    for i in range(num_taxis): 
        yield arr[i] 
ids = taxi_id_number(10)



def shift_info():
    start_times_and_freqs = [(0, 8), (8, 30), (16, 15)]
    indices = np.arange(len(start_times_and_freqs))
    while True:
        idx = np.random.choice(indices, p = [0.25, 0.5, 0.25])
        start = start_times_and_freqs[idx]
        yield (start[0], start[0] + 7.5, start[1])
ids = shift_info()

for i in range(1,100):
    print(next(ids))

from dataclasses import dataclass
@dataclass
class TimePoint:
    taxi_id: int
    name: str
    time: float
    def __lt__(self, other):
        return self.time < other.time


def taxi_process(taxi_id_generator, shift_info_generator):
    taxi_id = next(taxi_id_generator)
    shift_start, shift_end, shift_mean_trips = next(shift_info_generator)
    actual_trips = round(np.random.normal(loc = shift_mean_trips, scale = 2))
    average_trip_time = 6.5 / shift_mean_trips * 60
    # Obliczenie średniego czasu jednego przejazdu
    between_events_time = 1.0 / (shift_mean_trips - 1) * 60
    # Nasze miasto jest bardzo wydajnie zorganizowane, dlatego  taksówki są praktycznie zawsze w użyciu
    time = shift_start
    yield TimePoint(taxi_id, 'rozpoczynam zmianę', time)
    deltaT = np.random.poisson(between_events_time) / 60
    time += deltaT
    for i in range(actual_trips):
        yield TimePoint(taxi_id, 'początek kursu ', time) 
        deltaT = np.random.poisson(average_trip_time)
        time += deltaT
        yield TimePoint(taxi_id, 'koniec kursu ', time)
        deltaT = np.random.poisson(between_events_time) / 60
        time += deltaT
    deltaT = np.random.poisson(between_events_time) / 60 
    time += deltaT
    yield TimePoint(taxi_id, 'koniec zmiany ', time)

import queue
class Simulator:
    def __init__(self, num_taxis):
        self._time_points = queue.PriorityQueue()
        taxi_id_generator =   taxi_id_number(num_taxis)
        shift_info_generator = shift_info()
        self._taxis = [taxi_process(taxi_id_generator,shift_info_generator) for i in range(num_taxis)]
        self._prepare_run()

    def _prepare_run(self):
        for t in self._taxis:
            while True:
                try:
                    e = next(t)
                    self._time_points.put(e)
                except:
                    break
    def run(self):
        sim_time = 0
        while sim_time < 24:
            if self._time_points.empty():
                break
            p = self._time_points.get()
            sim_time = p.time
            print(p)

sim = Simulator(1000)
sim.run()
# Out:
# (8, 15.5, 30)
# (8, 15.5, 30)
# (0, 7.5, 8)
# (0, 7.5, 8)
# (8, 15.5, 30)
# (8, 15.5, 30)
# (8, 15.5, 30)
# (0, 7.5, 8)
# (0, 7.5, 8)
# (16, 23.5, 15)
# (8, 15.5, 30)
# (8, 15.5, 30)
# (16, 23.5, 15)
# (16, 23.5, 15)
# (16, 23.5, 15)
# (0, 7.5, 8)
# (16, 23.5, 15)
# (0, 7.5, 8)
# (8, 15.5, 30)
# (0, 7.5, 8)
# (8, 15.5, 30)
# (8, 15.5, 30)
# (0, 7.5, 8)
# (0, 7.5, 8)
# (8, 15.5, 30)
# (8, 15.5, 30)
# (8, 15.5, 30)
# (0, 7.5, 8)
# (8, 15.5, 30)
# (8, 15.5, 30)
# (0, 7.5, 8)
# (8, 15.5, 30)
# (16, 23.5, 15)
# (8, 15.5, 30)
# (8, 15.5, 30)
# (8, 15.5, 30)
# (8, 15.5, 30)
# (8, 15.5, 30)
# (8, 15.5, 30)
# (0, 7.5, 8)
# (8, 15.5, 30)
# (8, 15.5, 30)
# (8, 15.5, 30)
# (8, 15.5, 30)
# (8, 15.5, 30)
# (0, 7.5, 8)
# (8, 15.5, 30)
# (16, 23.5, 15)
# (0, 7.5, 8)
# (16, 23.5, 15)
# (8, 15.5, 30)
# (16, 23.5, 15)
# (8, 15.5, 30)
# (16, 23.5, 15)
# (16, 23.5, 15)
# (0, 7.5, 8)
# (16, 23.5, 15)
# (0, 7.5, 8)
# (8, 15.5, 30)
# (16, 23.5, 15)
# (16, 23.5, 15)
# (16, 23.5, 15)
# (0, 7.5, 8)
# (16, 23.5, 15)
# (8, 15.5, 30)
# (8, 15.5, 30)
# (16, 23.5, 15)
# (8, 15.5, 30)
# (0, 7.5, 8)
# (16, 23.5, 15)
# (16, 23.5, 15)
# (8, 15.5, 30)
# (0, 7.5, 8)
# (0, 7.5, 8)
# (8, 15.5, 30)
# (8, 15.5, 30)
# (16, 23.5, 15)
# (0, 7.5, 8)
# (8, 15.5, 30)
# (8, 15.5, 30)
# (16, 23.5, 15)
# (0, 7.5, 8)
# (16, 23.5, 15)
# (16, 23.5, 15)
# (16, 23.5, 15)
# (16, 23.5, 15)
# (8, 15.5, 30)
# (8, 15.5, 30)
# (8, 15.5, 30)
# (0, 7.5, 8)
# (8, 15.5, 30)
# (8, 15.5, 30)
# (8, 15.5, 30)
# (0, 7.5, 8)
# (16, 23.5, 15)
# (0, 7.5, 8)
# (16, 23.5, 15)
# (8, 15.5, 30)
# (16, 23.5, 15)
# TimePoint(taxi_id=915, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=844, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=799, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=606, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=190, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=939, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=152, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=829, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=139, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=332, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=406, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=486, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=315, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=158, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=818, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=510, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=896, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=240, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=432, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=462, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=361, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=347, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=754, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=614, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=88, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=440, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=945, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=525, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=484, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=182, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=338, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=536, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=609, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=579, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=78, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=472, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=195, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=760, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=452, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=652, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=526, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=137, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=304, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=997, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=262, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=902, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=669, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=728, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=318, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=308, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=12, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=695, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=766, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=25, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=948, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=75, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=555, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=99, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=967, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=811, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=363, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=931, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=56, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=32, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=289, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=797, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=474, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=466, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=899, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=664, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=211, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=345, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=236, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=215, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=208, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=212, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=761, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=730, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=2, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=250, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=685, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=610, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=408, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=559, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=502, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=785, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=749, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=567, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=747, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=791, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=935, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=483, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=325, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=569, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=677, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=97, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=38, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=978, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=80, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=537, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=987, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=407, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=738, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=118, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=235, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=833, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=471, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=323, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=954, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=890, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=143, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=1, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=586, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=67, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=404, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=133, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=447, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=398, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=793, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=170, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=654, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=204, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=817, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=561, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=612, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=41, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=269, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=848, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=433, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=530, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=988, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=70, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=180, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=605, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=964, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=639, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=217, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=93, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=89, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=9, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=286, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=210, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=774, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=925, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=903, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=209, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=743, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=280, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=626, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=173, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=437, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=814, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=625, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=772, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=374, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=82, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=86, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=53, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=65, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=413, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=255, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=912, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=691, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=296, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=864, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=638, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=589, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=206, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=868, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=888, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=385, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=981, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=470, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=79, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=256, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=324, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=601, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=335, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=314, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=199, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=784, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=122, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=311, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=519, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=867, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=913, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=587, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=515, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=943, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=571, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=220, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=121, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=222, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=288, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=656, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=764, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=165, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=295, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=381, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=590, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=976, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=841, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=493, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=562, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=34, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=857, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=671, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=107, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=213, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=937, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=362, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=175, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=109, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=353, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=352, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=96, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=523, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=475, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=596, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=119, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=823, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=68, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=253, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=717, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=826, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=478, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=748, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=129, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=188, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=287, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=228, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=995, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=924, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=963, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=429, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=991, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=83, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=694, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=873, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=742, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=975, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=955, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=507, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=869, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=594, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=159, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=100, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=372, name='rozpoczynam zmianę', time=0)
# TimePoint(taxi_id=997, name='początek kursu ', time=0.016666666666666666)
# TimePoint(taxi_id=925, name='początek kursu ', time=0.03333333333333333)
# TimePoint(taxi_id=589, name='początek kursu ', time=0.03333333333333333)
# TimePoint(taxi_id=262, name='początek kursu ', time=0.05)
# TimePoint(taxi_id=669, name='początek kursu ', time=0.05)
# TimePoint(taxi_id=99, name='początek kursu ', time=0.05)
# TimePoint(taxi_id=954, name='początek kursu ', time=0.05)
# TimePoint(taxi_id=170, name='początek kursu ', time=0.05)
# TimePoint(taxi_id=799, name='początek kursu ', time=0.06666666666666667)
# TimePoint(taxi_id=606, name='początek kursu ', time=0.06666666666666667)
# TimePoint(taxi_id=754, name='początek kursu ', time=0.06666666666666667)
# TimePoint(taxi_id=437, name='początek kursu ', time=0.06666666666666667)
# TimePoint(taxi_id=912, name='początek kursu ', time=0.06666666666666667)
# TimePoint(taxi_id=913, name='początek kursu ', time=0.06666666666666667)
# TimePoint(taxi_id=109, name='początek kursu ', time=0.06666666666666667)
# TimePoint(taxi_id=748, name='początek kursu ', time=0.06666666666666667)
# TimePoint(taxi_id=963, name='początek kursu ', time=0.06666666666666667)
# TimePoint(taxi_id=873, name='początek kursu ', time=0.06666666666666667)
# TimePoint(taxi_id=432, name='początek kursu ', time=0.08333333333333333)
# TimePoint(taxi_id=78, name='początek kursu ', time=0.08333333333333333)
# TimePoint(taxi_id=761, name='początek kursu ', time=0.08333333333333333)
# TimePoint(taxi_id=654, name='początek kursu ', time=0.08333333333333333)
# TimePoint(taxi_id=561, name='początek kursu ', time=0.08333333333333333)
# TimePoint(taxi_id=180, name='początek kursu ', time=0.08333333333333333)
# TimePoint(taxi_id=964, name='początek kursu ', time=0.08333333333333333)
# TimePoint(taxi_id=217, name='początek kursu ', time=0.08333333333333333)
# TimePoint(taxi_id=9, name='początek kursu ', time=0.08333333333333333)
# TimePoint(taxi_id=210, name='początek kursu ', time=0.08333333333333333)
# TimePoint(taxi_id=86, name='początek kursu ', time=0.08333333333333333)
# TimePoint(taxi_id=470, name='początek kursu ', time=0.08333333333333333)
# TimePoint(taxi_id=841, name='początek kursu ', time=0.08333333333333333)
# TimePoint(taxi_id=976, name='początek kursu ', time=0.08333333333333333)
# TimePoint(taxi_id=107, name='początek kursu ', time=0.08333333333333333)
# TimePoint(taxi_id=287, name='początek kursu ', time=0.08333333333333333)
# TimePoint(taxi_id=869, name='początek kursu ', time=0.08333333333333333)
# TimePoint(taxi_id=614, name='początek kursu ', time=0.1)
# TimePoint(taxi_id=88, name='początek kursu ', time=0.1)
# TimePoint(taxi_id=945, name='początek kursu ', time=0.1)
# TimePoint(taxi_id=472, name='początek kursu ', time=0.1)
# TimePoint(taxi_id=609, name='początek kursu ', time=0.1)
# TimePoint(taxi_id=12, name='początek kursu ', time=0.1)
# TimePoint(taxi_id=695, name='początek kursu ', time=0.1)
# TimePoint(taxi_id=466, name='początek kursu ', time=0.1)
# TimePoint(taxi_id=236, name='początek kursu ', time=0.1)
# TimePoint(taxi_id=208, name='początek kursu ', time=0.1)
# TimePoint(taxi_id=685, name='początek kursu ', time=0.1)
# TimePoint(taxi_id=483, name='początek kursu ', time=0.1)
# TimePoint(taxi_id=978, name='początek kursu ', time=0.1)
# TimePoint(taxi_id=70, name='początek kursu ', time=0.1)
# TimePoint(taxi_id=206, name='początek kursu ', time=0.1)
# TimePoint(taxi_id=314, name='początek kursu ', time=0.1)
# TimePoint(taxi_id=867, name='początek kursu ', time=0.1)
# TimePoint(taxi_id=295, name='początek kursu ', time=0.1)
# TimePoint(taxi_id=362, name='początek kursu ', time=0.1)
# TimePoint(taxi_id=34, name='początek kursu ', time=0.1)
# TimePoint(taxi_id=83, name='początek kursu ', time=0.1)
# TimePoint(taxi_id=507, name='początek kursu ', time=0.1)
# TimePoint(taxi_id=240, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=440, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=338, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=137, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=652, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=766, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=931, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=215, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=569, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=677, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=935, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=738, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=833, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=447, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=890, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=41, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=286, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=625, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=65, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=888, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=256, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=335, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=784, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=199, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=515, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=82, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=943, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=671, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=253, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=717, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=129, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=995, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=478, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=991, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=562, name='początek kursu ', time=0.11666666666666667)
# TimePoint(taxi_id=152, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=139, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=332, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=896, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=361, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=902, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=308, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=32, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=211, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=797, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=730, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=785, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=749, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=97, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=559, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=118, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=987, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=471, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=404, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=408, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=848, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=433, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=639, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=173, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=79, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=601, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=122, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=519, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=523, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=475, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=119, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=228, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=694, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=955, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=975, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=372, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=742, name='początek kursu ', time=0.13333333333333333)
# TimePoint(taxi_id=939, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=158, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=510, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=182, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=760, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=844, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=948, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=967, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=56, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=345, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=2, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=567, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=325, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=80, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=537, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=586, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=530, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=988, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=296, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=638, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=385, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=324, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=981, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=311, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=288, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=590, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=213, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=857, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=353, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=159, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=594, name='początek kursu ', time=0.15)
# TimePoint(taxi_id=486, name='początek kursu ', time=0.16666666666666666)
# TimePoint(taxi_id=406, name='początek kursu ', time=0.16666666666666666)
# TimePoint(taxi_id=818, name='początek kursu ', time=0.16666666666666666)
# TimePoint(taxi_id=315, name='początek kursu ', time=0.16666666666666666)
# TimePoint(taxi_id=347, name='początek kursu ', time=0.16666666666666666)
# TimePoint(taxi_id=579, name='początek kursu ', time=0.16666666666666666)
# TimePoint(taxi_id=318, name='początek kursu ', time=0.16666666666666666)
# TimePoint(taxi_id=25, name='początek kursu ', time=0.16666666666666666)
# TimePoint(taxi_id=75, name='początek kursu ', time=0.16666666666666666)
# TimePoint(taxi_id=664, name='początek kursu ', time=0.16666666666666666)
# TimePoint(taxi_id=289, name='początek kursu ', time=0.16666666666666666)
# TimePoint(taxi_id=502, name='początek kursu ', time=0.16666666666666666)
# TimePoint(taxi_id=323, name='początek kursu ', time=0.16666666666666666)
# TimePoint(taxi_id=269, name='początek kursu ', time=0.16666666666666666)
# TimePoint(taxi_id=605, name='początek kursu ', time=0.16666666666666666)
# TimePoint(taxi_id=903, name='początek kursu ', time=0.16666666666666666)
# TimePoint(taxi_id=743, name='początek kursu ', time=0.16666666666666666)
# TimePoint(taxi_id=612, name='początek kursu ', time=0.16666666666666666)
# TimePoint(taxi_id=220, name='początek kursu ', time=0.16666666666666666)
# TimePoint(taxi_id=121, name='początek kursu ', time=0.16666666666666666)
# TimePoint(taxi_id=656, name='początek kursu ', time=0.16666666666666666)
# TimePoint(taxi_id=222, name='początek kursu ', time=0.16666666666666666)
# TimePoint(taxi_id=937, name='początek kursu ', time=0.16666666666666666)
# TimePoint(taxi_id=96, name='początek kursu ', time=0.16666666666666666)
# TimePoint(taxi_id=100, name='początek kursu ', time=0.16666666666666666)
# TimePoint(taxi_id=915, name='początek kursu ', time=0.16666666666666666)
# TimePoint(taxi_id=924, name='początek kursu ', time=0.16666666666666666)
# TimePoint(taxi_id=304, name='początek kursu ', time=0.18333333333333332)
# TimePoint(taxi_id=452, name='początek kursu ', time=0.18333333333333332)
# TimePoint(taxi_id=728, name='początek kursu ', time=0.18333333333333332)
# TimePoint(taxi_id=811, name='początek kursu ', time=0.18333333333333332)
# TimePoint(taxi_id=212, name='początek kursu ', time=0.18333333333333332)
# TimePoint(taxi_id=747, name='początek kursu ', time=0.18333333333333332)
# TimePoint(taxi_id=791, name='początek kursu ', time=0.18333333333333332)
# TimePoint(taxi_id=407, name='początek kursu ', time=0.18333333333333332)
# TimePoint(taxi_id=235, name='początek kursu ', time=0.18333333333333332)
# TimePoint(taxi_id=143, name='początek kursu ', time=0.18333333333333332)
# TimePoint(taxi_id=793, name='początek kursu ', time=0.18333333333333332)
# TimePoint(taxi_id=774, name='początek kursu ', time=0.18333333333333332)
# TimePoint(taxi_id=626, name='początek kursu ', time=0.18333333333333332)
# TimePoint(taxi_id=53, name='początek kursu ', time=0.18333333333333332)
# TimePoint(taxi_id=868, name='początek kursu ', time=0.18333333333333332)
# TimePoint(taxi_id=587, name='początek kursu ', time=0.18333333333333332)
# TimePoint(taxi_id=610, name='początek kursu ', time=0.18333333333333332)
# TimePoint(taxi_id=493, name='początek kursu ', time=0.18333333333333332)
# TimePoint(taxi_id=352, name='początek kursu ', time=0.18333333333333332)
# TimePoint(taxi_id=826, name='początek kursu ', time=0.18333333333333332)
# TimePoint(taxi_id=596, name='początek kursu ', time=0.18333333333333332)
# TimePoint(taxi_id=429, name='początek kursu ', time=0.18333333333333332)
# TimePoint(taxi_id=190, name='początek kursu ', time=0.2)
# TimePoint(taxi_id=525, name='początek kursu ', time=0.2)
# TimePoint(taxi_id=484, name='początek kursu ', time=0.2)
# TimePoint(taxi_id=555, name='początek kursu ', time=0.2)
# TimePoint(taxi_id=250, name='początek kursu ', time=0.2)
# TimePoint(taxi_id=398, name='początek kursu ', time=0.2)
# TimePoint(taxi_id=1, name='początek kursu ', time=0.2)
# TimePoint(taxi_id=67, name='początek kursu ', time=0.2)
# TimePoint(taxi_id=204, name='początek kursu ', time=0.2)
# TimePoint(taxi_id=89, name='początek kursu ', time=0.2)
# TimePoint(taxi_id=280, name='początek kursu ', time=0.2)
# TimePoint(taxi_id=772, name='początek kursu ', time=0.2)
# TimePoint(taxi_id=814, name='początek kursu ', time=0.2)
# TimePoint(taxi_id=764, name='początek kursu ', time=0.2)
# TimePoint(taxi_id=165, name='początek kursu ', time=0.2)
# TimePoint(taxi_id=381, name='początek kursu ', time=0.2)
# TimePoint(taxi_id=68, name='początek kursu ', time=0.2)
# TimePoint(taxi_id=823, name='początek kursu ', time=0.2)
# TimePoint(taxi_id=188, name='początek kursu ', time=0.2)
# TimePoint(taxi_id=374, name='początek kursu ', time=0.2)
# TimePoint(taxi_id=829, name='początek kursu ', time=0.21666666666666667)
# TimePoint(taxi_id=462, name='początek kursu ', time=0.21666666666666667)
# TimePoint(taxi_id=536, name='początek kursu ', time=0.21666666666666667)
# TimePoint(taxi_id=195, name='początek kursu ', time=0.21666666666666667)
# TimePoint(taxi_id=363, name='początek kursu ', time=0.21666666666666667)
# TimePoint(taxi_id=899, name='początek kursu ', time=0.21666666666666667)
# TimePoint(taxi_id=38, name='początek kursu ', time=0.21666666666666667)
# TimePoint(taxi_id=255, name='początek kursu ', time=0.21666666666666667)
# TimePoint(taxi_id=691, name='początek kursu ', time=0.21666666666666667)
# TimePoint(taxi_id=175, name='początek kursu ', time=0.21666666666666667)
# TimePoint(taxi_id=474, name='początek kursu ', time=0.23333333333333334)
# TimePoint(taxi_id=133, name='początek kursu ', time=0.23333333333333334)
# TimePoint(taxi_id=817, name='początek kursu ', time=0.23333333333333334)
# TimePoint(taxi_id=864, name='początek kursu ', time=0.23333333333333334)
# TimePoint(taxi_id=571, name='początek kursu ', time=0.23333333333333334)
# TimePoint(taxi_id=526, name='początek kursu ', time=0.25)
# TimePoint(taxi_id=209, name='początek kursu ', time=0.25)
# TimePoint(taxi_id=413, name='początek kursu ', time=0.25)
# TimePoint(taxi_id=93, name='początek kursu ', time=0.26666666666666666)
# TimePoint(taxi_id=55, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=492, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=795, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=663, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=274, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=201, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=815, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=51, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=354, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=200, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=72, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=892, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=775, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=14, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=443, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=126, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=852, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=454, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=151, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=35, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=808, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=479, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=687, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=438, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=659, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=234, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=798, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=512, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=60, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=431, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=384, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=882, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=851, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=851, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=76, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=498, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=225, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=805, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=805, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=421, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=16, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=563, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=563, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=655, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=229, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=247, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=247, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=205, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=611, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=974, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=765, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=268, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=693, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=765, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=373, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=838, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=37, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=918, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=666, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=540, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=540, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=0, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=221, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=360, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=104, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=279, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=184, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=426, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=184, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=391, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=307, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=307, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=751, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=379, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=379, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=751, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=43, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=297, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=620, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=459, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=464, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=871, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=66, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=871, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=482, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=696, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=15, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=905, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=179, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=629, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=958, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=958, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=101, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=782, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=271, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=708, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=678, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=434, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=456, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=719, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=111, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=358, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=971, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=949, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=949, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=990, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=102, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=622, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=622, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=169, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=334, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=334, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=370, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=489, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=715, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=715, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=154, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=364, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=706, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=138, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=651, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=839, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=344, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=577, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=405, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=737, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=825, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=402, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=956, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=736, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=756, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=736, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=572, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=481, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=252, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=658, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=285, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=532, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=285, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=77, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=801, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=947, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=928, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=849, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=508, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=517, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=701, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=276, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=623, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=232, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=357, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=254, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=473, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=623, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=246, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=36, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=230, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=419, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=763, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=763, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=885, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=557, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=557, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=942, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=422, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=422, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=294, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=953, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=322, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=450, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=450, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=425, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=501, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=339, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=439, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=342, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=342, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=853, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=198, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=539, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=518, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=114, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=130, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=804, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=130, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=29, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=326, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=500, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=675, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=449, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=449, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=952, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=227, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=103, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=103, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=603, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=74, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=927, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=300, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=351, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=243, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=909, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=558, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=223, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=744, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=806, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=744, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=542, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=883, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=6, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=549, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=816, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=365, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=149, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=786, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=392, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=3, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=237, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=660, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=922, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=922, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=551, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=794, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=242, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=699, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=181, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=665, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=750, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=700, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=117, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=134, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=746, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=807, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=746, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=393, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=393, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=898, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=986, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=248, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=248, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=673, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=957, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=722, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=513, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=781, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=509, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=394, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=123, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=123, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=480, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=480, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=39, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=39, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=854, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=33, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=48, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=48, name='początek kursu ', time=8.0)
# TimePoint(taxi_id=866, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=112, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=136, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=930, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=777, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=435, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=535, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=58, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=595, name='rozpoczynam zmianę', time=8)
# TimePoint(taxi_id=863, name='rozpoczynam zmianę', time=8)
# ...
# TimePoint(taxi_id=43, name='początek kursu ', time=21.083333333333332)
# TimePoint(taxi_id=149, name='początek kursu ', time=21.083333333333332)
# TimePoint(taxi_id=369, name='początek kursu ', time=21.083333333333332)
# TimePoint(taxi_id=292, name='początek kursu ', time=21.083333333333332)
# TimePoint(taxi_id=179, name='koniec kursu ', time=21.083333333333336)
# TimePoint(taxi_id=863, name='koniec kursu ', time=21.083333333333336)
# TimePoint(taxi_id=141, name='początek kursu ', time=21.083333333333336)
# TimePoint(taxi_id=196, name='początek kursu ', time=21.083333333333336)
# TimePoint(taxi_id=377, name='początek kursu ', time=21.083333333333336)
# TimePoint(taxi_id=382, name='koniec kursu ', time=21.083333333333336)
# TimePoint(taxi_id=921, name='początek kursu ', time=21.099999999999998)
# TimePoint(taxi_id=863, name='początek kursu ', time=21.1)
# TimePoint(taxi_id=423, name='koniec kursu ', time=21.1)
# TimePoint(taxi_id=382, name='początek kursu ', time=21.1)
# TimePoint(taxi_id=659, name='początek kursu ', time=21.116666666666664)
# TimePoint(taxi_id=683, name='początek kursu ', time=21.133333333333333)
# TimePoint(taxi_id=179, name='początek kursu ', time=21.133333333333336)
# TimePoint(taxi_id=423, name='początek kursu ', time=21.150000000000002)
# TimePoint(taxi_id=557, name='początek kursu ', time=22.0)
# TimePoint(taxi_id=557, name='koniec kursu ', time=22.0)
# TimePoint(taxi_id=422, name='koniec kursu ', time=22.0)
# TimePoint(taxi_id=49, name='koniec kursu ', time=22.0)
# TimePoint(taxi_id=647, name='koniec kursu ', time=22.0)
# TimePoint(taxi_id=904, name='koniec kursu ', time=22.0)
# TimePoint(taxi_id=498, name='koniec kursu ', time=22.016666666666666)
# TimePoint(taxi_id=344, name='koniec kursu ', time=22.016666666666666)
# TimePoint(taxi_id=422, name='początek kursu ', time=22.016666666666666)
# TimePoint(taxi_id=365, name='koniec kursu ', time=22.016666666666666)
# TimePoint(taxi_id=237, name='koniec kursu ', time=22.016666666666666)
# TimePoint(taxi_id=907, name='koniec kursu ', time=22.016666666666666)
# TimePoint(taxi_id=496, name='koniec kursu ', time=22.016666666666666)
# TimePoint(taxi_id=879, name='koniec kursu ', time=22.016666666666666)
# TimePoint(taxi_id=400, name='koniec kursu ', time=22.016666666666666)
# TimePoint(taxi_id=724, name='koniec kursu ', time=22.016666666666666)
# TimePoint(taxi_id=965, name='koniec kursu ', time=22.016666666666666)
# TimePoint(taxi_id=186, name='koniec kursu ', time=22.016666666666666)
# TimePoint(taxi_id=574, name='koniec kursu ', time=22.016666666666666)
# TimePoint(taxi_id=94, name='koniec kursu ', time=22.016666666666666)
# TimePoint(taxi_id=94, name='początek kursu ', time=22.016666666666666)
# TimePoint(taxi_id=278, name='koniec kursu ', time=22.016666666666666)
# TimePoint(taxi_id=613, name='koniec kursu ', time=22.016666666666666)
# TimePoint(taxi_id=313, name='koniec kursu ', time=22.016666666666666)
# TimePoint(taxi_id=904, name='początek kursu ', time=22.016666666666666)
# TimePoint(taxi_id=458, name='koniec kursu ', time=22.016666666666666)
# TimePoint(taxi_id=649, name='koniec kursu ', time=22.016666666666666)
# TimePoint(taxi_id=663, name='koniec kursu ', time=22.03333333333333)
# TimePoint(taxi_id=72, name='koniec kursu ', time=22.03333333333333)
# TimePoint(taxi_id=431, name='koniec kursu ', time=22.03333333333333)
# TimePoint(taxi_id=498, name='początek kursu ', time=22.03333333333333)
# TimePoint(taxi_id=655, name='koniec kursu ', time=22.03333333333333)
# TimePoint(taxi_id=655, name='początek kursu ', time=22.03333333333333)
# TimePoint(taxi_id=974, name='koniec kursu ', time=22.03333333333333)
# TimePoint(taxi_id=696, name='koniec kursu ', time=22.03333333333333)
# TimePoint(taxi_id=532, name='koniec kursu ', time=22.03333333333333)
# TimePoint(taxi_id=227, name='koniec kursu ', time=22.03333333333333)
# TimePoint(taxi_id=237, name='początek kursu ', time=22.03333333333333)
# TimePoint(taxi_id=922, name='koniec kursu ', time=22.03333333333333)
# TimePoint(taxi_id=898, name='koniec kursu ', time=22.03333333333333)
# TimePoint(taxi_id=907, name='początek kursu ', time=22.03333333333333)
# TimePoint(taxi_id=859, name='koniec kursu ', time=22.03333333333333)
# TimePoint(taxi_id=682, name='koniec kursu ', time=22.03333333333333)
# TimePoint(taxi_id=619, name='koniec kursu ', time=22.03333333333333)
# TimePoint(taxi_id=879, name='początek kursu ', time=22.03333333333333)
# TimePoint(taxi_id=721, name='koniec kursu ', time=22.03333333333333)
# TimePoint(taxi_id=574, name='początek kursu ', time=22.03333333333333)
# TimePoint(taxi_id=263, name='koniec kursu ', time=22.03333333333333)
# TimePoint(taxi_id=216, name='koniec kursu ', time=22.03333333333333)
# TimePoint(taxi_id=238, name='początek kursu ', time=22.03333333333333)
# TimePoint(taxi_id=238, name='koniec kursu ', time=22.03333333333333)
# TimePoint(taxi_id=458, name='początek kursu ', time=22.03333333333333)
# TimePoint(taxi_id=649, name='początek kursu ', time=22.03333333333333)
# TimePoint(taxi_id=608, name='koniec kursu ', time=22.03333333333333)
# TimePoint(taxi_id=647, name='początek kursu ', time=22.033333333333335)
# TimePoint(taxi_id=227, name='początek kursu ', time=22.049999999999997)
# TimePoint(taxi_id=263, name='początek kursu ', time=22.049999999999997)
# TimePoint(taxi_id=14, name='koniec kursu ', time=22.05)
# TimePoint(taxi_id=205, name='koniec kursu ', time=22.05)
# TimePoint(taxi_id=611, name='koniec kursu ', time=22.05)
# TimePoint(taxi_id=344, name='początek kursu ', time=22.05)
# TimePoint(taxi_id=825, name='koniec kursu ', time=22.05)
# TimePoint(taxi_id=326, name='koniec kursu ', time=22.05)
# TimePoint(taxi_id=914, name='koniec kursu ', time=22.05)
# TimePoint(taxi_id=400, name='początek kursu ', time=22.05)
# TimePoint(taxi_id=613, name='początek kursu ', time=22.05)
# TimePoint(taxi_id=95, name='koniec kursu ', time=22.05)
# TimePoint(taxi_id=153, name='koniec kursu ', time=22.05)
# TimePoint(taxi_id=72, name='początek kursu ', time=22.066666666666666)
# TimePoint(taxi_id=431, name='początek kursu ', time=22.066666666666666)
# TimePoint(taxi_id=696, name='początek kursu ', time=22.066666666666666)
# TimePoint(taxi_id=114, name='koniec kursu ', time=22.066666666666666)
# TimePoint(taxi_id=49, name='początek kursu ', time=22.066666666666666)
# TimePoint(taxi_id=859, name='początek kursu ', time=22.066666666666666)
# TimePoint(taxi_id=724, name='początek kursu ', time=22.066666666666666)
# TimePoint(taxi_id=876, name='koniec kursu ', time=22.066666666666666)
# TimePoint(taxi_id=278, name='początek kursu ', time=22.066666666666666)
# TimePoint(taxi_id=216, name='początek kursu ', time=22.066666666666666)
# TimePoint(taxi_id=608, name='początek kursu ', time=22.066666666666666)
# TimePoint(taxi_id=663, name='początek kursu ', time=22.083333333333332)
# TimePoint(taxi_id=532, name='początek kursu ', time=22.083333333333332)
# TimePoint(taxi_id=365, name='początek kursu ', time=22.083333333333332)
# TimePoint(taxi_id=922, name='początek kursu ', time=22.083333333333332)
# TimePoint(taxi_id=682, name='początek kursu ', time=22.083333333333332)
# TimePoint(taxi_id=721, name='początek kursu ', time=22.083333333333332)
# TimePoint(taxi_id=313, name='początek kursu ', time=22.083333333333332)
# TimePoint(taxi_id=14, name='początek kursu ', time=22.083333333333336)
# TimePoint(taxi_id=205, name='początek kursu ', time=22.083333333333336)
# TimePoint(taxi_id=825, name='początek kursu ', time=22.083333333333336)
# TimePoint(taxi_id=252, name='koniec kursu ', time=22.083333333333336)
# TimePoint(taxi_id=163, name='koniec kursu ', time=22.083333333333336)
# TimePoint(taxi_id=95, name='początek kursu ', time=22.083333333333336)
# TimePoint(taxi_id=153, name='początek kursu ', time=22.083333333333336)
# TimePoint(taxi_id=898, name='początek kursu ', time=22.099999999999998)
# TimePoint(taxi_id=496, name='początek kursu ', time=22.099999999999998)
# TimePoint(taxi_id=965, name='początek kursu ', time=22.099999999999998)
# TimePoint(taxi_id=326, name='początek kursu ', time=22.1)
# TimePoint(taxi_id=619, name='początek kursu ', time=22.116666666666664)
# TimePoint(taxi_id=243, name='koniec kursu ', time=22.116666666666667)
# TimePoint(taxi_id=876, name='początek kursu ', time=22.116666666666667)
# TimePoint(taxi_id=252, name='początek kursu ', time=22.11666666666667)
# TimePoint(taxi_id=974, name='początek kursu ', time=22.133333333333333)
# TimePoint(taxi_id=611, name='początek kursu ', time=22.133333333333333)
# TimePoint(taxi_id=114, name='początek kursu ', time=22.133333333333333)
# TimePoint(taxi_id=914, name='początek kursu ', time=22.133333333333333)
# TimePoint(taxi_id=186, name='początek kursu ', time=22.133333333333333)
# TimePoint(taxi_id=243, name='początek kursu ', time=22.150000000000002)
# TimePoint(taxi_id=163, name='początek kursu ', time=22.150000000000002)
# TimePoint(taxi_id=765, name='początek kursu ', time=23.0)
# TimePoint(taxi_id=765, name='koniec kursu ', time=23.0)
# TimePoint(taxi_id=871, name='koniec kursu ', time=23.0)
# TimePoint(taxi_id=736, name='koniec kursu ', time=23.0)
# TimePoint(taxi_id=285, name='koniec kursu ', time=23.0)
# TimePoint(taxi_id=386, name='koniec kursu ', time=23.0)
# TimePoint(taxi_id=386, name='początek kursu ', time=23.0)
# TimePoint(taxi_id=421, name='koniec kursu ', time=23.016666666666666)
# TimePoint(taxi_id=0, name='koniec kursu ', time=23.016666666666666)
# TimePoint(taxi_id=871, name='początek kursu ', time=23.016666666666666)
# TimePoint(taxi_id=990, name='koniec kursu ', time=23.016666666666666)
# TimePoint(taxi_id=138, name='koniec kursu ', time=23.016666666666666)
# TimePoint(taxi_id=736, name='początek kursu ', time=23.016666666666666)
# TimePoint(taxi_id=942, name='koniec kursu ', time=23.016666666666666)
# TimePoint(taxi_id=340, name='koniec kursu ', time=23.016666666666666)
# TimePoint(taxi_id=468, name='koniec kursu ', time=23.016666666666666)
# TimePoint(taxi_id=185, name='koniec kursu ', time=23.016666666666666)
# TimePoint(taxi_id=661, name='koniec kursu ', time=23.016666666666666)
# TimePoint(taxi_id=933, name='koniec kursu ', time=23.016666666666666)
# TimePoint(taxi_id=877, name='koniec kursu ', time=23.016666666666666)
# TimePoint(taxi_id=37, name='koniec kursu ', time=23.03333333333333)
# TimePoint(taxi_id=687, name='koniec kursu ', time=23.03333333333333)
# TimePoint(taxi_id=358, name='koniec kursu ', time=23.03333333333333)
# TimePoint(taxi_id=517, name='koniec kursu ', time=23.03333333333333)
# TimePoint(taxi_id=74, name='początek kursu ', time=23.03333333333333)
# TimePoint(taxi_id=74, name='koniec kursu ', time=23.03333333333333)
# TimePoint(taxi_id=786, name='koniec kursu ', time=23.03333333333333)
# TimePoint(taxi_id=794, name='koniec kursu ', time=23.03333333333333)
# TimePoint(taxi_id=448, name='koniec kursu ', time=23.03333333333333)
# TimePoint(taxi_id=661, name='początek kursu ', time=23.03333333333333)
# TimePoint(taxi_id=933, name='początek kursu ', time=23.03333333333333)
# TimePoint(taxi_id=707, name='koniec kursu ', time=23.03333333333333)
# TimePoint(taxi_id=707, name='początek kursu ', time=23.03333333333333)
# TimePoint(taxi_id=959, name='koniec kursu ', time=23.03333333333333)
# TimePoint(taxi_id=491, name='koniec kursu ', time=23.03333333333333)
# TimePoint(taxi_id=940, name='koniec kursu ', time=23.03333333333333)
# TimePoint(taxi_id=327, name='koniec kursu ', time=23.03333333333333)
# TimePoint(taxi_id=992, name='koniec kursu ', time=23.03333333333333)
# TimePoint(taxi_id=894, name='koniec kursu ', time=23.03333333333333)
# TimePoint(taxi_id=894, name='początek kursu ', time=23.03333333333333)
# TimePoint(taxi_id=513, name='koniec kursu ', time=23.033333333333335)
# TimePoint(taxi_id=786, name='początek kursu ', time=23.049999999999997)
# TimePoint(taxi_id=794, name='początek kursu ', time=23.049999999999997)
# TimePoint(taxi_id=448, name='początek kursu ', time=23.049999999999997)
# TimePoint(taxi_id=940, name='początek kursu ', time=23.049999999999997)
# TimePoint(taxi_id=421, name='początek kursu ', time=23.05)
# TimePoint(taxi_id=0, name='początek kursu ', time=23.05)
# TimePoint(taxi_id=360, name='koniec kursu ', time=23.05)
# TimePoint(taxi_id=426, name='koniec kursu ', time=23.05)
# TimePoint(taxi_id=971, name='koniec kursu ', time=23.05)
# TimePoint(taxi_id=971, name='początek kursu ', time=23.05)
# TimePoint(taxi_id=658, name='koniec kursu ', time=23.05)
# TimePoint(taxi_id=285, name='początek kursu ', time=23.05)
# TimePoint(taxi_id=230, name='koniec kursu ', time=23.05)
# TimePoint(taxi_id=185, name='początek kursu ', time=23.05)
# TimePoint(taxi_id=929, name='koniec kursu ', time=23.05)
# TimePoint(taxi_id=847, name='koniec kursu ', time=23.05)
# TimePoint(taxi_id=872, name='koniec kursu ', time=23.05)
# TimePoint(taxi_id=321, name='koniec kursu ', time=23.05)
# TimePoint(taxi_id=360, name='początek kursu ', time=23.066666666666666)
# TimePoint(taxi_id=990, name='początek kursu ', time=23.066666666666666)
# TimePoint(taxi_id=358, name='początek kursu ', time=23.066666666666666)
# TimePoint(taxi_id=138, name='początek kursu ', time=23.066666666666666)
# TimePoint(taxi_id=942, name='początek kursu ', time=23.066666666666666)
# TimePoint(taxi_id=665, name='koniec kursu ', time=23.066666666666666)
# TimePoint(taxi_id=340, name='początek kursu ', time=23.066666666666666)
# TimePoint(taxi_id=468, name='początek kursu ', time=23.066666666666666)
# TimePoint(taxi_id=672, name='koniec kursu ', time=23.066666666666666)
# TimePoint(taxi_id=877, name='początek kursu ', time=23.066666666666666)
# TimePoint(taxi_id=491, name='początek kursu ', time=23.066666666666666)
# TimePoint(taxi_id=929, name='początek kursu ', time=23.066666666666666)
# TimePoint(taxi_id=397, name='koniec kursu ', time=23.066666666666666)
# TimePoint(taxi_id=164, name='koniec kursu ', time=23.066666666666666)
# TimePoint(taxi_id=321, name='początek kursu ', time=23.066666666666666)
# TimePoint(taxi_id=327, name='początek kursu ', time=23.066666666666666)
# TimePoint(taxi_id=37, name='początek kursu ', time=23.083333333333332)
# TimePoint(taxi_id=672, name='początek kursu ', time=23.083333333333332)
# TimePoint(taxi_id=959, name='początek kursu ', time=23.083333333333332)
# TimePoint(taxi_id=992, name='początek kursu ', time=23.083333333333332)
# TimePoint(taxi_id=658, name='początek kursu ', time=23.083333333333336)
# TimePoint(taxi_id=230, name='początek kursu ', time=23.083333333333336)
# TimePoint(taxi_id=513, name='początek kursu ', time=23.083333333333336)
# TimePoint(taxi_id=866, name='koniec kursu ', time=23.083333333333336)
# TimePoint(taxi_id=266, name='koniec kursu ', time=23.083333333333336)
# TimePoint(taxi_id=45, name='koniec kursu ', time=23.083333333333336)
# TimePoint(taxi_id=389, name='koniec kursu ', time=23.083333333333336)
# TimePoint(taxi_id=872, name='początek kursu ', time=23.083333333333336)
# TimePoint(taxi_id=687, name='początek kursu ', time=23.099999999999998)
# TimePoint(taxi_id=517, name='początek kursu ', time=23.099999999999998)
# TimePoint(taxi_id=866, name='początek kursu ', time=23.1)
# TimePoint(taxi_id=266, name='początek kursu ', time=23.1)
# TimePoint(taxi_id=397, name='początek kursu ', time=23.1)
# TimePoint(taxi_id=164, name='początek kursu ', time=23.1)
# TimePoint(taxi_id=680, name='koniec kursu ', time=23.1)
# TimePoint(taxi_id=617, name='koniec kursu ', time=23.1)
# TimePoint(taxi_id=946, name='koniec kursu ', time=23.1)
# TimePoint(taxi_id=151, name='koniec kursu ', time=23.116666666666667)
# TimePoint(taxi_id=680, name='początek kursu ', time=23.116666666666667)
# TimePoint(taxi_id=19, name='koniec kursu ', time=23.116666666666667)
# TimePoint(taxi_id=946, name='początek kursu ', time=23.116666666666667)
# TimePoint(taxi_id=45, name='początek kursu ', time=23.11666666666667)
# TimePoint(taxi_id=426, name='początek kursu ', time=23.133333333333333)
# TimePoint(taxi_id=665, name='początek kursu ', time=23.133333333333333)
# TimePoint(taxi_id=847, name='początek kursu ', time=23.133333333333333)
# TimePoint(taxi_id=151, name='początek kursu ', time=23.150000000000002)
# TimePoint(taxi_id=389, name='początek kursu ', time=23.150000000000002)
# TimePoint(taxi_id=19, name='początek kursu ', time=23.166666666666668)
# TimePoint(taxi_id=617, name='początek kursu ', time=23.200000000000003)
# TimePoint(taxi_id=130, name='koniec kursu ', time=24.0)
